# %%
import pandas as pd

fert = pd.read_csv('gapminder_total_fertility.csv', index_col=0)
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73
# Zimbabwe               6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 5.69  5.64  5.59
# Zimbabwe               3.49  3.41  3.35
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx') # i can use the index_col = 0
life
# Out:
#            Life expectancy  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0                 Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1              Afghanistan   28.21   28.20   28.19   28.18   28.17   28.16
# 2    Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                  Albania   35.40   35.40   35.40   35.40   35.40   35.40
# 4                  Algeria   28.82   28.82   28.82   28.82   28.82   28.82
# ..                     ...     ...     ...     ...     ...     ...     ...
# 255             Yugoslavia     NaN     NaN     NaN     NaN     NaN     NaN
# 256                 Zambia   32.60   32.60   32.60   32.60   32.60   32.60
# 257               Zimbabwe   33.70   33.70   33.70   33.70   33.70   33.70
# 258                  Åland     NaN     NaN     NaN     NaN     NaN     NaN
# 259            South Sudan   26.67   26.67   26.67   26.67   26.67   26.67
#
#      1806.0  1807.0  1808.0  ...  2007.0  2008.0  2009.0  2010.0  2011.0  \
# 0       NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1     28.15   28.14   28.13  ...    52.4    52.8    53.3    53.6    54.0
# 2       NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3     35.40   35.40   35.40  ...    76.6    76.8    77.0    77.2    77.4
# 4     28.82   28.82   28.82  ...    75.3    75.5    75.7    76.0    76.1
# ..      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 255     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 256   32.60   32.60   32.60  ...    49.0    51.1    52.3    53.1    53.7
# 257   33.70   33.70   33.70  ...    46.4    47.3    48.0    49.1    51.6
# 258     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 259   26.67   26.67   26.67  ...    55.5    55.6    55.8    56.0    55.9
#
#      2012.0  2013.0  2014.0  2015.0  2016.0
# 0       NaN     NaN     NaN     NaN     NaN
# 1      54.4    54.8    54.9    53.8   52.72
# 2       NaN     NaN     NaN     NaN     NaN
# 3      77.5    77.7    77.9    78.0   78.10
# 4      76.2    76.3    76.3    76.4   76.50
# ..      ...     ...     ...     ...     ...
# 255     NaN     NaN     NaN     NaN     NaN
# 256    54.7    55.6    56.3    56.7   57.10
# 257    54.2    55.7    57.0    59.3   61.69
# 258     NaN     NaN     NaN     NaN     NaN
# 259    56.0    56.0    56.1    56.1   56.10
#
# [260 rows x 218 columns]

# %%
print(life.shape)
# Out:
# (260, 218)

# %%
print(fert.shape)
# Out:
# (260, 216)

# %%
life.columns
# Out:
# Index(['Life expectancy',            1800.0,            1801.0,
#                   1802.0,            1803.0,            1804.0,
#                   1805.0,            1806.0,            1807.0,
#                   1808.0,
#        ...
#                   2007.0,            2008.0,            2009.0,
#                   2010.0,            2011.0,            2012.0,
#                   2013.0,            2014.0,            2015.0,
#                   2016.0],
#       dtype='object', length=218)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.set_index('Life expectancy',inplace=True)

# %%
life
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
# ...                       ...     ...     ...     ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                  32.60   32.60   32.60   32.60   32.60   32.60   32.60
# Zimbabwe                33.70   33.70   33.70   33.70   33.70   33.70   33.70
# Åland                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# South Sudan             26.67   26.67   26.67   26.67   26.67   26.67   26.67
#
#                        1807.0  1808.0  1809.0  ...  2007.0  2008.0  2009.0  \
# Life expectancy                                ...
# Abkhazia                  NaN     NaN     NaN  ...     NaN     NaN     NaN
# Afghanistan             28.14   28.13   28.12  ...    52.4    52.8    53.3
# Akrotiri and Dhekelia     NaN     NaN     NaN  ...     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40  ...    76.6    76.8    77.0
# Algeria                 28.82   28.82   28.82  ...    75.3    75.5    75.7
# ...                       ...     ...     ...  ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN  ...     NaN     NaN     NaN
# Zambia                  32.60   32.60   32.60  ...    49.0    51.1    52.3
# Zimbabwe                33.70   33.70   33.70  ...    46.4    47.3    48.0
# Åland                     NaN     NaN     NaN  ...     NaN     NaN     NaN
# South Sudan             26.67   26.67   26.67  ...    55.5    55.6    55.8
#
#                        2010.0  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan              53.6    54.0    54.4    54.8    54.9    53.8   52.72
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                  77.2    77.4    77.5    77.7    77.9    78.0   78.10
# Algeria                  76.0    76.1    76.2    76.3    76.3    76.4   76.50
# ...                       ...     ...     ...     ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                   53.1    53.7    54.7    55.6    56.3    56.7   57.10
# Zimbabwe                 49.1    51.6    54.2    55.7    57.0    59.3   61.69
# Åland                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# South Sudan              56.0    55.9    56.0    56.0    56.1    56.1   56.10
#
# [260 rows x 217 columns]

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73
# Zimbabwe               6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 5.69  5.64  5.59
# Zimbabwe               3.49  3.41  3.35
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
life.columns
# Out:
# Index([1800.0, 1801.0, 1802.0, 1803.0, 1804.0, 1805.0, 1806.0, 1807.0, 1808.0,
#        1809.0,
#        ...
#        2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0,
#        2016.0],
#       dtype='object', length=217)

# %%
#fert.columns
fert.columns = fert.columns.astype(int)

# %%
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
life.columns = life.columns.astype(int)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %%
fert.index.name = 'country'

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# country                      ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  ...  5.93  5.91  5.88  5.85  5.81  5.77  5.73
# Zimbabwe               6.75  ...  3.94  3.90  3.85  3.79  3.72  3.64  3.56
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# country
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 5.69  5.64  5.59
# Zimbabwe               3.49  3.41  3.35
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
fert = fert.reset_index()

# %%
fert = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')

# %%
fert
# Out:
#                      country  year  fertility_rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
life.index
fert.index.name = 'country'
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria                28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
# ...                      ...    ...  ...   ...   ...   ...   ...   ...   ...
# Yugoslavia               NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 32.60  32.60  ...  49.0  51.1  52.3  53.1  53.7  54.7
# Zimbabwe               33.70  33.70  ...  46.4  47.3  48.0  49.1  51.6  54.2
# Åland                    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# South Sudan            26.67  26.67  ...  55.5  55.6  55.8  56.0  55.9  56.0
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
# Albania                77.7  77.9  78.0  78.10
# Algeria                76.3  76.3  76.4  76.50
# ...                     ...   ...   ...    ...
# Yugoslavia              NaN   NaN   NaN    NaN
# Zambia                 55.6  56.3  56.7  57.10
# Zimbabwe               55.7  57.0  59.3  61.69
# Åland                   NaN   NaN   NaN    NaN
# South Sudan            56.0  56.1  56.1  56.10
#
# [260 rows x 217 columns]

# %%
life.index.name = 'country'
life = life.reset_index()
life = life.melt(id_vars='country', var_name='year', value_name='life_expectancy')
life
# Out:
#                      country  year  life_expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
population = pd.read_excel('gapminder_population.xlsx',index_col = 0)
population
# Out:
#                                                  1800.0     1810.0     1820.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1830.0     1840.0     1850.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3448982.0  3625022.0  3810047.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        457234.0   478227.0   506889.0
# Algeria                                       2880355.0  3082721.0  3299305.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1860.0     1870.0     1880.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3973968.0  4169690.0  4419695.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        552800.0   610036.0   672544.0
# Algeria                                       3536468.0  3811028.0  4143163.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1890.0  ...      2006.0  \
# Total population                                         ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   4710171.0  ...  25183615.0
# Akrotiri and Dhekelia                               NaN  ...     15700.0
# Albania                                        741688.0  ...   3050741.0
# Algeria                                       4525691.0  ...  33749328.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                   2007.0      2008.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2009.0      2010.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   27207291.0  27962207.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2929886.0   2901883.0
# Algeria                                       35401790.0  36036159.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2011.0      2012.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   28809167.0  29726803.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2886010.0   2880667.0
# Algeria                                       36717132.0  37439427.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2013.0      2014.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   30682500.0  31627506.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2883281.0   2889676.0
# Algeria                                       38186135.0  38934334.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2015.0
# Total population
# Abkhazia                                             NaN
# Afghanistan                                   32526562.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2896679.0
# Algeria                                       39666519.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 81 columns]

# %%
population.info()
population.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, Abkhazia to West Bank
# Data columns (total 81 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1800.0  229 non-null    float64
#  1   1810.0  229 non-null    float64
#  2   1820.0  229 non-null    float64
#  3   1830.0  229 non-null    float64
#  4   1840.0  229 non-null    float64
#  5   1850.0  229 non-null    float64
#  6   1860.0  229 non-null    float64
#  7   1870.0  229 non-null    float64
#  8   1880.0  229 non-null    float64
#  9   1890.0  229 non-null    float64
#  10  1900.0  229 non-null    float64
#  11  1910.0  229 non-null    float64
#  12  1920.0  229 non-null    float64
#  13  1930.0  229 non-null    float64
#  14  1940.0  229 non-null    float64
#  15  1950.0  256 non-null    float64
#  16  1951.0  256 non-null    float64
#  17  1952.0  256 non-null    float64
#  18  1953.0  256 non-null    float64
#  19  1954.0  256 non-null    float64
#  20  1955.0  256 non-null    float64
#  21  1956.0  256 non-null    float64
#  22  1957.0  256 non-null    float64
#  23  1958.0  256 non-null    float64
#  24  1959.0  256 non-null    float64
#  25  1960.0  256 non-null    float64
#  26  1961.0  256 non-null    float64
#  27  1962.0  256 non-null    float64
#  28  1963.0  256 non-null    float64
#  29  1964.0  256 non-null    float64
#  30  1965.0  256 non-null    float64
#  31  1966.0  256 non-null    float64
#  32  1967.0  256 non-null    float64
#  33  1968.0  256 non-null    float64
#  34  1969.0  256 non-null    float64
#  35  1970.0  256 non-null    float64
#  36  1971.0  256 non-null    float64
#  37  1972.0  256 non-null    float64
#  38  1973.0  256 non-null    float64
#  39  1974.0  256 non-null    float64
#  40  1975.0  256 non-null    float64
#  41  1976.0  256 non-null    float64
#  42  1977.0  256 non-null    float64
#  43  1978.0  256 non-null    float64
#  44  1979.0  256 non-null    float64
#  45  1980.0  256 non-null    float64
#  46  1981.0  256 non-null    float64
#  47  1982.0  256 non-null    float64
#  48  1983.0  256 non-null    float64
#  49  1984.0  256 non-null    float64
#  50  1985.0  256 non-null    float64
#  51  1986.0  256 non-null    float64
#  52  1987.0  256 non-null    float64
#  53  1988.0  256 non-null    float64
#  54  1989.0  256 non-null    float64
#  55  1990.0  256 non-null    float64
#  56  1991.0  256 non-null    float64
#  57  1992.0  256 non-null    float64
#  58  1993.0  256 non-null    float64
#  59  1994.0  256 non-null    float64
#  60  1995.0  256 non-null    float64
#  61  1996.0  256 non-null    float64
#  62  1997.0  256 non-null    float64
#  63  1998.0  256 non-null    float64
#  64  1999.0  256 non-null    float64
#  65  2000.0  256 non-null    float64
#  66  2001.0  256 non-null    float64
#  67  2002.0  256 non-null    float64
#  68  2003.0  256 non-null    float64
#  69  2004.0  256 non-null    float64
#  70  2005.0  256 non-null    float64
#  71  2006.0  256 non-null    float64
#  72  2007.0  256 non-null    float64
#  73  2008.0  256 non-null    float64
#  74  2009.0  238 non-null    float64
#  75  2010.0  238 non-null    float64
#  76  2011.0  233 non-null    float64
#  77  2012.0  233 non-null    float64
#  78  2013.0  233 non-null    float64
#  79  2014.0  231 non-null    float64
#  80  2015.0  231 non-null    float64
# dtypes: float64(81)
# memory usage: 176.2+ KB
#              1800.0        1810.0        1820.0        1830.0        1840.0  \
# count  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02
# mean   4.137832e+06  4.330692e+06  4.561516e+06  4.822455e+06  5.066513e+06
# std    2.422799e+07  2.601555e+07  2.789334e+07  2.941603e+07  3.018315e+07
# min    1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 25%    4.390800e+04  4.390800e+04  4.467300e+04  4.689400e+04  4.764300e+04
# 50%    4.010000e+05  4.133260e+05  4.235270e+05  4.535070e+05  4.782270e+05
# 75%    1.894389e+06  1.904962e+06  1.983383e+06  2.101048e+06  2.186704e+06
# max    3.216750e+08  3.505430e+08  3.800553e+08  4.023735e+08  4.112134e+08
#
#              1850.0        1860.0        1870.0        1880.0        1890.0  \
# count  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02
# mean   5.250450e+06  5.398263e+06  5.609144e+06  5.945787e+06  6.376547e+06
# std    2.995424e+07  2.898546e+07  2.846866e+07  2.904625e+07  3.022539e+07
# min    1.090000e+02  1.390000e+02  1.910000e+02  2.590000e+02  3.520000e+02
# 25%    5.340500e+04  6.446900e+04  6.542200e+04  6.817000e+04  6.922200e+04
# 50%    5.443020e+05  5.959280e+05  6.599300e+05  7.139570e+05  7.432100e+05
# 75%    2.236808e+06  2.399360e+06  2.596105e+06  2.822978e+06  3.088808e+06
# max    4.027113e+08  3.800475e+08  3.636612e+08  3.655442e+08  3.771353e+08
#
#        ...        2006.0        2007.0        2008.0        2009.0  \
# count  ...  2.560000e+02  2.560000e+02  2.560000e+02  2.380000e+02
# mean   ...  2.813600e+07  2.846652e+07  2.880011e+07  2.876698e+07
# std    ...  1.149097e+08  1.160131e+08  1.171146e+08  1.212191e+08
# min    ...  5.000000e+01  5.000000e+01  5.000000e+01  5.000000e+01
# 25%    ...  2.868232e+05  2.928408e+05  2.989525e+05  3.174302e+05
# 50%    ...  4.521912e+06  4.561442e+06  4.636136e+06  4.523432e+06
# 75%    ...  1.711520e+07  1.764428e+07  1.819443e+07  1.676626e+07
# max    ...  1.312601e+09  1.319625e+09  1.326691e+09  1.333807e+09
#
#              2010.0        2011.0        2012.0        2013.0        2014.0  \
# count  2.380000e+02  2.330000e+02  2.330000e+02  2.330000e+02  2.310000e+02
# mean   2.911667e+07  3.010052e+07  3.046134e+07  3.082280e+07  3.135238e+07
# std    1.223602e+08  1.247404e+08  1.258755e+08  1.270003e+08  1.286516e+08
# min    5.000000e+01  7.990000e+02  7.990000e+02  7.990000e+02  7.990000e+02
# 25%    3.243505e+05  3.994430e+05  4.055120e+05  4.114990e+05  4.175585e+05
# 50%    4.581304e+06  4.953945e+06  5.018367e+06  5.240088e+06  5.307188e+06
# 75%    1.691918e+07  2.011166e+07  1.994495e+07  1.932259e+07  1.894310e+07
# max    1.340969e+09  1.348174e+09  1.355387e+09  1.362514e+09  1.369436e+09
#
#              2015.0
# count  2.310000e+02
# mean   3.171457e+07
# std    1.297556e+08
# min    8.000000e+02
# 25%    4.209290e+05
# 50%    5.373502e+06
# 75%    1.900687e+07
# max    1.376049e+09
#
# [8 rows x 81 columns]

# %%
fert.reset_index(drop=True,inplace=True)

# %%
life
# Out:
#                      country  year  life_expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
df = fert.merge(life)

# %%
population
# Out:
#                                                  1800.0     1810.0     1820.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1830.0     1840.0     1850.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3448982.0  3625022.0  3810047.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        457234.0   478227.0   506889.0
# Algeria                                       2880355.0  3082721.0  3299305.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1860.0     1870.0     1880.0  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3973968.0  4169690.0  4419695.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        552800.0   610036.0   672544.0
# Algeria                                       3536468.0  3811028.0  4143163.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                  1890.0  ...      2006.0  \
# Total population                                         ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   4710171.0  ...  25183615.0
# Akrotiri and Dhekelia                               NaN  ...     15700.0
# Albania                                        741688.0  ...   3050741.0
# Algeria                                       4525691.0  ...  33749328.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                   2007.0      2008.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2009.0      2010.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   27207291.0  27962207.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2929886.0   2901883.0
# Algeria                                       35401790.0  36036159.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2011.0      2012.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   28809167.0  29726803.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2886010.0   2880667.0
# Algeria                                       36717132.0  37439427.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2013.0      2014.0  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   30682500.0  31627506.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2883281.0   2889676.0
# Algeria                                       38186135.0  38934334.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                   2015.0
# Total population
# Abkhazia                                             NaN
# Afghanistan                                   32526562.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2896679.0
# Algeria                                       39666519.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 81 columns]

# %%
population.index.name = 'country'
population = population.reset_index()
population = population.melt(id_vars='country', var_name='year', value_name='population')

# %%
population
# Out:
#                                             country    year  population
# 0                                          Abkhazia  1800.0         NaN
# 1                                       Afghanistan  1800.0   3280000.0
# 2                             Akrotiri and Dhekelia  1800.0         NaN
# 3                                           Albania  1800.0    410445.0
# 4                                           Algeria  1800.0   2503218.0
# ...                                             ...     ...         ...
# 22270                             Northern Marianas  2015.0         NaN
# 22271  South Georgia and the South Sandwich Islands  2015.0         NaN
# 22272                     US Minor Outlying Islands  2015.0         NaN
# 22273                                Virgin Islands  2015.0         NaN
# 22274                                     West Bank  2015.0         NaN
#
# [22275 rows x 3 columns]

# %%
final_data = df.merge(population)

# %%
final_data[final_data['year']==2000]
final_data['population'] = final_data['population'] / 1#0000
final_data
# Out:
#                      country  year  fertility_rate  life_expectancy  \
# 0                   Abkhazia  1800             NaN              NaN
# 1                Afghanistan  1800            7.00            28.21
# 2      Akrotiri and Dhekelia  1800             NaN              NaN
# 3                    Albania  1800            4.60            35.40
# 4                    Algeria  1800            6.99            28.82
# ...                      ...   ...             ...              ...
# 20974             Yugoslavia  2015             NaN              NaN
# 20975                 Zambia  2015            5.59            56.70
# 20976               Zimbabwe  2015            3.35            59.30
# 20977                  Åland  2015             NaN              NaN
# 20978                  Åland  2015             NaN              NaN
#
#        population
# 0             NaN
# 1       3280000.0
# 2             NaN
# 3        410445.0
# 4       2503218.0
# ...           ...
# 20974         NaN
# 20975  16211767.0
# 20976  15602751.0
# 20977         NaN
# 20978         NaN
#
# [20979 rows x 5 columns]

# %%
continents = pd.read_csv('continents.csv',sep = ';')
continents
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


cmap = sns.cubehelix_palette(rot=-.4, as_cmap=True, reverse =False)
df_subset = final_data.loc[final_data['year'] == 2000]
p =sns.scatterplot(data=df_subset, size = 'population', 
    alpha=.7, sizes = (30,350),hue="population",palette = 'seismic',
    x="life_expectancy", y="fertility_rate"
    )
p.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), ncol=1)

# %%
for year in range(1960,2015):
    df_subset = final_data.loc[final_data['year'] == year]
    p =sns.scatterplot(data=df_subset, size = 'population', 
        alpha=.6, sizes = (30,350),hue="population",palette = 'seismic',
        x="life_expectancy", y="fertility_rate"
        )
    p.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), ncol=1)
    plt.ylim(0, 10)
    plt.xlim(25, 90)
    plt.axis((0,10,25,90))
    plt.savefig(f'lifeexp_{year}.png')
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/08/6zrs8w253573k0k0yjq1w49c0000gn/T/ipykernel_39486/3438323622.py in <module>
#       1 for year in range(1960,2015):
# ----> 2     df_subset = final_data.loc[final_data['year'] == year]
#       3     p =sns.scatterplot(data=df_subset, size = 'population',
#       4         alpha=.6, sizes = (30,350),hue="population",palette = 'seismic',
#       5         x="life_expectancy", y="fertility_rate"
#
# NameError: name 'final_data' is not defined

# %%
import imageio
import os

images = []

for i in range(1960, 2015):
    filename = 'lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('output.gif', images, fps=10)
for year in range(1960, 2015):
    os.remove(f'lifeexp_{year}.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/08/6zrs8w253573k0k0yjq1w49c0000gn/T/ipykernel_23660/312314838.py in <module>
#       6 for i in range(1960, 2015):
#       7     filename = 'lifeexp_{}.png'.format(i)
# ----> 8     images.append(imageio.imread(filename))
#       9
#      10 imageio.mimsave('output.gif', images, fps=10)
#
# /opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# /opt/anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     170
#     171     # Create request object
# --> 172     request = Request(uri, "r" + mode, **kwargs)
#     173
#     174     # Get format
#
# /opt/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     122
#     123         # Parse what was given
# --> 124         self._parse_uri(uri)
#     125
#     126         # Set extension
#
# /opt/anaconda3/lib/python3.7/site-packages/imageio/core/request.py in _parse_uri(self, uri)
#     258                 # Reading: check that the file exists (but is allowed a dir)
#     259                 if not os.path.exists(fn):
# --> 260                     raise FileNotFoundError("No such file: '%s'" % fn)
#     261             else:
#     262                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/Users/alexandros.samartzis/Spiced_Academy/stationary-sriracha-student-code/Week_1/spiced_projects/lifeexp_1960.png'
