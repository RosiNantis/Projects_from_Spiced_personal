# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df = pd.read_csv('./population.csv') # upload the data

# %%
df #see data set
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
df.index # see index
# Out:
# RangeIndex(start=0, stop=275, step=1)

# %%
df.columns  # see columns
# Out:
# Index(['Total population', '1800', '1810', '1820', '1830', '1840', '1850',
#        '1860', '1870', '1880', '1890', '1900', '1910', '1920', '1930', '1940',
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958',
#        '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=275, step=1)

# %%
df.head() # returns the first columns of the list
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %%
df
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
df.index = df['Total population']

# %%
df['Total population']
# Out:
# Total population
# Abkhazia                                                                            Abkhazia
# Afghanistan                                                                      Afghanistan
# Akrotiri and Dhekelia                                                  Akrotiri and Dhekelia
# Albania                                                                              Albania
# Algeria                                                                              Algeria
#                                                                     ...
# Northern Marianas                                                          Northern Marianas
# South Georgia and the South Sandwich Islands    South Georgia and the South Sandwich Islands
# US Minor Outlying Islands                                          US Minor Outlying Islands
# Virgin Islands                                                                Virgin Islands
# ...

# %%
df.index = df['Total population']

# %%
df.head()
# Out:
#                             Total population       1800       1810       1820  \
# Total population
# Abkhazia                            Abkhazia        NaN        NaN        NaN
# Afghanistan                      Afghanistan  3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia  Akrotiri and Dhekelia        NaN        NaN        NaN
# Albania                              Albania   410445.0   423591.0   438671.0
# Algeria                              Algeria  2503218.0  2595056.0  2713079.0
#
#                             1830       1840       1850       1860       1870  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3448982.0  3625022.0  3810047.0  3973968.0  4169690.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 457234.0   478227.0   506889.0   552800.0   610036.0
# Algeria                2880355.0  3082721.0  3299305.0  3536468.0  3811028.0
# ...

# %%
df['1800']
# Out:
# Total population
# Abkhazia                                              NaN
# Afghanistan                                     3280000.0
# Akrotiri and Dhekelia                                 NaN
# Albania                                          410445.0
# Algeria                                         2503218.0
#                                                   ...
# Northern Marianas                                     NaN
# South Georgia and the South Sandwich Islands          NaN
# US Minor Outlying Islands                             NaN
# Virgin Islands                                        NaN
# West Bank                                             NaN
# Name: 1800, Length: 275, dtype: float64

# %%
df_clean = df.drop('Total population',axis = 1) #Get read of extra column

# %%
df_clean.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
df_clean[['1900']] # take a list of columns
# Out:
#                                                    1900
# Total population
# Abkhazia                                            NaN
# Afghanistan                                   5021241.0
# Akrotiri and Dhekelia                               NaN
# Albania                                        819950.0
# Algeria                                       4946166.0
# ...                                                 ...
# Northern Marianas                                   NaN
# South Georgia and the South Sandwich Islands        NaN
# US Minor Outlying Islands                           NaN
# Virgin Islands                                      NaN
# West Bank                                           NaN
#
# [275 rows x 1 columns]

# %%
df_clean.loc['Albania','1950']
# Out:
# 1263171.0

# %%
df_clean.iloc[5:10,5:10] # df_clean.loc['Andora':'Germany', '1890':'1900']
# Out:
#                           1850       1860       1870       1880       1890
# Total population
# American Samoa          7958.0     7564.0     7057.0     6582.0     6139.0
# Andorra                 3230.0     3436.0     3654.0     3885.0     4131.0
# Angola               1949329.0  2110747.0  2285417.0  2473597.0  2677047.0
# Anguilla                2511.0     2693.0     2888.0     3097.0     3320.0
# Antigua and Barbuda    37000.0    36532.0    35546.0    35222.0    36286.0

# %%
df_clean[df_clean['1900'] > 50000000]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Germany            22886919.0   23882461.0   25507768.0   28016571.0
# India             168574895.0  171940819.0  176225709.0  182214537.0
# Russia             31088398.0   31088398.0   31861526.0   34134430.0
# United States       6801854.0    8294928.0   10361646.0   13480460.0
#
#                          1840         1850         1860         1870  \
# Total population
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Germany            31016143.0   33663143.0   36383150.0   39702235.0
# India             189298397.0  196657653.0  204966302.0  213725049.0
# Russia             37420913.0   41023821.0   44966686.0   49288504.0
# United States      17942443.0   24136293.0   31936643.0   40821569.0
#
#                          1880         1890  ...          2006          2007  \
# ...

# %%
df_clean.where(df_clean['1900'] > 50000000)
# Out:
#                                               1800  1810  1820  1830  1840  \
# Total population
# Abkhazia                                       NaN   NaN   NaN   NaN   NaN
# Afghanistan                                    NaN   NaN   NaN   NaN   NaN
# Akrotiri and Dhekelia                          NaN   NaN   NaN   NaN   NaN
# Albania                                        NaN   NaN   NaN   NaN   NaN
# Algeria                                        NaN   NaN   NaN   NaN   NaN
# ...                                            ...   ...   ...   ...   ...
# Northern Marianas                              NaN   NaN   NaN   NaN   NaN
# South Georgia and the South Sandwich Islands   NaN   NaN   NaN   NaN   NaN
# US Minor Outlying Islands                      NaN   NaN   NaN   NaN   NaN
# Virgin Islands                                 NaN   NaN   NaN   NaN   NaN
# West Bank                                      NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df_clean['1985'].isna().sum() # sum the data that are NaN in column 1985
# Out:
# 19

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, Abkhazia to West Bank
# Data columns (total 81 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1800    229 non-null    float64
#  1   1810    229 non-null    float64
#  2   1820    229 non-null    float64
#  3   1830    229 non-null    float64
#  4   1840    229 non-null    float64
#  5   1850    229 non-null    float64
#  6   1860    229 non-null    float64
#  7   1870    229 non-null    float64
#  8   1880    229 non-null    float64
#  9   1890    229 non-null    float64
#  10  1900    229 non-null    float64
#  11  1910    229 non-null    float64
#  12  1920    229 non-null    float64
#  13  1930    229 non-null    float64
#  14  1940    229 non-null    float64
#  15  1950    256 non-null    float64
#  16  1951    256 non-null    float64
#  17  1952    256 non-null    float64
#  18  1953    256 non-null    float64
#  19  1954    256 non-null    float64
# ...

# %%
df_clean.describe()
# Out:
#                1800          1810          1820          1830          1840  \
# count  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02
# mean   4.137832e+06  4.330692e+06  4.561516e+06  4.822455e+06  5.066513e+06
# std    2.422799e+07  2.601555e+07  2.789334e+07  2.941603e+07  3.018315e+07
# min    1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 25%    4.390800e+04  4.390800e+04  4.467300e+04  4.689400e+04  4.764300e+04
# 50%    4.010000e+05  4.133260e+05  4.235270e+05  4.535070e+05  4.782270e+05
# 75%    1.894389e+06  1.904962e+06  1.983383e+06  2.101048e+06  2.186704e+06
# max    3.216750e+08  3.505430e+08  3.800553e+08  4.023735e+08  4.112134e+08
#
#                1850          1860          1870          1880          1890  \
# count  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02  2.290000e+02
# mean   5.250450e+06  5.398263e+06  5.609144e+06  5.945787e+06  6.376547e+06
# ...

# %% [markdown]
# ## Read and Save Files

# %%
pd.read_csv('./population.csv', sep = ',')
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
#df_clean['1800'].hist()

# %% [markdown]
# # what are pros and cons of using pandas over Excel?
# ## faster and gives to user more power to do the task
#
# # what should you check when a filename is wrong?
#
# # what options can you use when loading a file into pandas?
#
# # how can you check quickly what a DataFrame contains?
#
# # what is the difference between DataFrames and Series?
#
# # what are advantages of pandas over Python lists and dictionaries?
