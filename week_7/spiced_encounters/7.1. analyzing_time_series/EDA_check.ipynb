# %% [markdown]
# ## Project 5: Time series analysis

# %%
import sys
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import rc
import numpy as np
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression


mpl.rcParams['axes.linewidth'] = 2 #set the value globally
rc('font',**{'family':'serif','serif':['Computer Modern']})
rc('text', usetex=False)
mpl.rc('xtick', labelsize=20)
mpl.rc('ytick', labelsize=20)
plt.rc('axes', labelsize=20) 
mpl.rcParams["xtick.minor.visible"] =  True
mpl.rcParams["ytick.minor.visible"] =  True
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['ytick.minor.size'] = 5

# %%
df = pd.read_csv('ECA_blended_custom/TG_STAID002759.txt',sep=',',skiprows=18,parse_dates=True,index_col='    DATE')

# %%
# df=df[df[' Q_TG']==0]

# %%
df.columns
# Out:
# Index([' SOUID', '   TG', ' Q_TG'], dtype='object')

# %%
df=df.drop(columns=[' SOUID',' Q_TG'])

# %%
df.columns
# Out:
# Index(['   TG'], dtype='object')

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['   TG'].replace(-9999, pd.NA , inplace=True)

# %%
df
# Out:
#               TG
#     DATE
# 1876-01-01    22
# 1876-01-02    25
# 1876-01-03     3
# 1876-01-04   -58
# 1876-01-05   -98
# ...          ...
# 2022-03-27    97
# 2022-03-28   108
# 2022-03-29    80
# 2022-03-30    53
# 2022-03-31  <NA>
#
# [53416 rows x 1 columns]

# %%
#Fix the temperature
df['temp']=df['   TG']*0.1

# %%
df
# Out:
#               TG  temp
#     DATE
# 1876-01-01    22   2.2
# 1876-01-02    25   2.5
# 1876-01-03     3   0.3
# 1876-01-04   -58  -5.8
# 1876-01-05   -98  -9.8
# ...          ...   ...
# 2022-03-27    97   9.7
# 2022-03-28   108  10.8
# 2022-03-29    80   8.0
# 2022-03-30    53   5.3
# 2022-03-31  <NA>  <NA>
#
# [53416 rows x 2 columns]

# %%
# Get year/month/day 
# df['YEAR']=df['    DATE'].astype(str).str[:4]
# df['MONTH']=df['    DATE'].astype(str).str[4:6]
# df['DAY']=df['    DATE'].astype(str).str[6:8]
# df['YEAR']=df['YEAR'].astype(int)
# df['MONTH']=df['MONTH'].astype(int)
# df['DAY']=df['DAY'].astype(int)

# %%
df['month']=df.index.month_name()
df['year']=df.index.year
df['day']=df.index.day_name()
df['quarter']=df.index.quarter
df['dayofyear']=df.index.day_of_year
df['weekofyear']=df.index.weekofyear
# Out:
# C:\ProgramData\Anaconda2\envs\py3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)

# %%
df
# Out:
#               TG  temp    month  year        day  quarter  dayofyear  \
#     DATE
# 1876-01-01    22   2.2  January  1876   Saturday        1          1
# 1876-01-02    25   2.5  January  1876     Sunday        1          2
# 1876-01-03     3   0.3  January  1876     Monday        1          3
# 1876-01-04   -58  -5.8  January  1876    Tuesday        1          4
# 1876-01-05   -98  -9.8  January  1876  Wednesday        1          5
# ...          ...   ...      ...   ...        ...      ...        ...
# 2022-03-27    97   9.7    March  2022     Sunday        1         86
# 2022-03-28   108  10.8    March  2022     Monday        1         87
# 2022-03-29    80   8.0    March  2022    Tuesday        1         88
# 2022-03-30    53   5.3    March  2022  Wednesday        1         89
# 2022-03-31  <NA>  <NA>    March  2022   Thursday        1         90
#
#             weekofyear
#     DATE
# 1876-01-01          52
# 1876-01-02          52
# 1876-01-03           1
# 1876-01-04           1
# 1876-01-05           1
# ...                ...
# 2022-03-27          12
# 2022-03-28          13
# 2022-03-29          13
# 2022-03-30          13
# 2022-03-31          13
#
# [53416 rows x 8 columns]

# %%
#create chart in each subplot
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp')
# sns.lineplot(data=df, x='year', y='temp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp'>

# %%
df
# Out:
#               TG  temp    month  year        day  quarter  dayofyear  \
#     DATE
# 1876-01-01    22   2.2  January  1876   Saturday        1          1
# 1876-01-02    25   2.5  January  1876     Sunday        1          2
# 1876-01-03     3   0.3  January  1876     Monday        1          3
# 1876-01-04   -58  -5.8  January  1876    Tuesday        1          4
# 1876-01-05   -98  -9.8  January  1876  Wednesday        1          5
# ...          ...   ...      ...   ...        ...      ...        ...
# 2022-03-27    97   9.7    March  2022     Sunday        1         86
# 2022-03-28   108  10.8    March  2022     Monday        1         87
# 2022-03-29    80   8.0    March  2022    Tuesday        1         88
# 2022-03-30    53   5.3    March  2022  Wednesday        1         89
# 2022-03-31  <NA>  <NA>    March  2022   Thursday        1         90
#
#             weekofyear
#     DATE
# 1876-01-01          52
# 1876-01-02          52
# 1876-01-03           1
# 1876-01-04           1
# 1876-01-05           1
# ...                ...
# 2022-03-27          12
# 2022-03-28          13
# 2022-03-29          13
# 2022-03-30          13
# 2022-03-31          13
#
# [53416 rows x 8 columns]

# %%
# df['temp'].replace(-999.9, pd.NA , inplace=True)
# df['temp']=df['temp'].replace('-999.9',np.nan)
# df.loc[df['   TG'] == '-9999.0'] = np.NaN

# %%
#Last Observation Carried Forward (LOCF)
df['temp_locf']= df['temp'].fillna(method ='bfill')

# %%
#Next Observation Carried Backward (NOCB)
df['temp_nocb']= df['temp'].fillna(method ='ffill')

# %%
#Interpolation
df['temp_interp']= df['temp'].interpolate(method='time')

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp_interp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp_interp'>

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp_nocb')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp_nocb'>

# %%
#Last Observation Carried Forward (LOCF)
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp_locf')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp_locf'>

# %%
df['timestep'] = list(range(len(df)))

# %%
# Run a Linear Regression
m = LinearRegression()
X = df[['timestep']]
y = df['temp_nocb']
m.fit(X, y)
# Out:
# LinearRegression()

# %%
df['trend'] = m.predict(X)
df.head()
# Out:
#               TG temp    month  year        day  quarter  dayofyear  \
#     DATE
# 1876-01-01    22  2.2  January  1876   Saturday        1          1
# 1876-01-02    25  2.5  January  1876     Sunday        1          2
# 1876-01-03     3  0.3  January  1876     Monday        1          3
# 1876-01-04   -58 -5.8  January  1876    Tuesday        1          4
# 1876-01-05   -98 -9.8  January  1876  Wednesday        1          5
#
#             weekofyear temp_locf  temp_nocb temp_interp  timestep     trend
#     DATE
# 1876-01-01          52       2.2        2.2         2.2         0  8.512586
# 1876-01-02          52       2.5        2.5         2.5         1  8.512619
# 1876-01-03           1       0.3        0.3         0.3         2  8.512651
# 1876-01-04           1      -5.8       -5.8        -5.8         3  8.512684
# 1876-01-05           1      -9.8       -9.8        -9.8         4  8.512717

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp_nocb')
sns.lineplot(data=df, x='year', y='trend')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp_nocb'>

# %%
pd.get_dummies(df.index.month, prefix='month').set_index(df.index)
# Out:
#             month_1  month_2  month_3  month_4  month_5  month_6  month_7  \
#     DATE
# 1876-01-01        1        0        0        0        0        0        0
# 1876-01-02        1        0        0        0        0        0        0
# 1876-01-03        1        0        0        0        0        0        0
# 1876-01-04        1        0        0        0        0        0        0
# 1876-01-05        1        0        0        0        0        0        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 2022-03-27        0        0        1        0        0        0        0
# 2022-03-28        0        0        1        0        0        0        0
# 2022-03-29        0        0        1        0        0        0        0
# 2022-03-30        0        0        1        0        0        0        0
# 2022-03-31        0        0        1        0        0        0        0
#
#             month_8  month_9  month_10  month_11  month_12
#     DATE
# 1876-01-01        0        0         0         0         0
# 1876-01-02        0        0         0         0         0
# 1876-01-03        0        0         0         0         0
# 1876-01-04        0        0         0         0         0
# 1876-01-05        0        0         0         0         0
# ...             ...      ...       ...       ...       ...
# 2022-03-27        0        0         0         0         0
# 2022-03-28        0        0         0         0         0
# 2022-03-29        0        0         0         0         0
# 2022-03-30        0        0         0         0         0
# 2022-03-31        0        0         0         0         0
#
# [53416 rows x 12 columns]

# %%
seasonal_dummies = pd.get_dummies(df.index.month,
                                  prefix='month',
                                  drop_first=True).set_index(df.index)
# sklearn.preprocessing.OneHotEncoder

df = df.join(seasonal_dummies)

# %%
df.columns
# Out:
# Index(['   TG', 'temp', 'month', 'year', 'day', 'quarter', 'dayofyear',
#        'weekofyear', 'temp_locf', 'temp_nocb', 'temp_interp', 'timestep',
#        'trend', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6',
#        'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12'],
#       dtype='object')

# %%
X = df.drop(columns=['   TG', 'temp', 'month', 'year', 'day', 'quarter', 'dayofyear',
       'weekofyear', 'temp_locf', 'temp_nocb', 'temp_interp', 'trend'])

# %%
X
# Out:
#             timestep  month_2  month_3  month_4  month_5  month_6  month_7  \
#     DATE
# 1876-01-01         0        0        0        0        0        0        0
# 1876-01-02         1        0        0        0        0        0        0
# 1876-01-03         2        0        0        0        0        0        0
# 1876-01-04         3        0        0        0        0        0        0
# 1876-01-05         4        0        0        0        0        0        0
# ...              ...      ...      ...      ...      ...      ...      ...
# 2022-03-27     53411        0        1        0        0        0        0
# 2022-03-28     53412        0        1        0        0        0        0
# 2022-03-29     53413        0        1        0        0        0        0
# 2022-03-30     53414        0        1        0        0        0        0
# 2022-03-31     53415        0        1        0        0        0        0
#
#             month_8  month_9  month_10  month_11  month_12
#     DATE
# 1876-01-01        0        0         0         0         0
# 1876-01-02        0        0         0         0         0
# 1876-01-03        0        0         0         0         0
# 1876-01-04        0        0         0         0         0
# 1876-01-05        0        0         0         0         0
# ...             ...      ...       ...       ...       ...
# 2022-03-27        0        0         0         0         0
# 2022-03-28        0        0         0         0         0
# 2022-03-29        0        0         0         0         0
# 2022-03-30        0        0         0         0         0
# 2022-03-31        0        0         0         0         0
#
# [53416 rows x 12 columns]

# %%
m.fit(X, y)
# Out:
# LinearRegression()

# %%
df['trend_seasonal'] = m.predict(X)

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='year', y='temp_nocb')
sns.lineplot(data=df, x='year', y='trend_seasonal')
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp_nocb'>

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='timestep', y='temp_nocb')
sns.lineplot(data=df, x='timestep', y='trend_seasonal')
plt.xlim(1000, 3000)
# Out:
# (1000.0, 3000.0)

# %%
# fig, axes = plt.subplots(1)
# fig.set_size_inches(14, 4)
df[['temp_nocb', 'trend_seasonal']].plot(figsize=(14, 4))
plt.xlim(1000, 3000)
# Out:
# (1000.0, 3000.0)

# %%
fig, axes = plt.subplots(1)
fig.set_size_inches(14, 4)
sns.lineplot(data=df, x='timestep', y='temp_nocb')
sns.lineplot(data=df, x='timestep', y='trend_seasonal')
# Out:
# <AxesSubplot:xlabel='timestep', ylabel='temp_nocb'>

# %%
df[['temp_nocb', 'trend_seasonal']].plot(figsize=(14, 4))
# plt.xlim(1000, 3000)
# Out:
# <AxesSubplot:xlabel='    DATE'>

# %%
df['remainder'] = df['temp_nocb'] - df['trend_seasonal']

# %%
df['remainder'].plot(figsize=(14, 4))
# Out:
# <AxesSubplot:xlabel='    DATE'>

# %%
df['remainder'].plot(figsize=(14, 4))
plt.xlim(1000, 3000)
# Out:
# (1000.0, 3000.0)

# %%
# ohc = OneHotEncoder(sparse=False, handle_unknown='ignore')

# # 2. fit with the training data (some columns of it)
# ohc.fit(df[['month']])

# # 3. transform the training data
# onehot= ohc.transform(df['month'])
# cols_ohc = pd.DataFrame(onehot, columns=ohc.get_feature_names_out())
# cols_ohc
