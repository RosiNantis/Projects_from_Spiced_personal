# %%
# !pip install  pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (1.8.4)
# Requirement already satisfied: pandas>=0.19 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: numpy>=1.19.3 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.21.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (58.0.4)
# Requirement already satisfied: urllib3 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: joblib>=0.11 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/arjunharidas/miniforge3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.4)

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf

plt.style.use('seaborn-white')

# %% [markdown]
# # sARIMA
#
# Goal: Forecast the value of $y_{t} $ based on past values $y_{t-1}, y_{t-2}, \dots$.
#
# $$
# y_{t} = F(y_{t-1}, y_{t-2}, \dots) + \epsilon_t
# $$
#
#
# ## Integrated I(d)
#
# > To remove the trend (mean stationary), it is differenced $d$ times before model estimation.
#
# $$
# \Delta y_t = y_t - y_{t-1}
# $$
#
#
# ## Autoregressive AR(p)
#
# > The current value of the time-series can be modeled as a weighted sum of past values of the forecast variable.
#
# $$
# F_{AR}(y_{t-1}, y_{t-2}, \dots) = \alpha_1y_{t-1} + \alpha_2y_{t-2} + \dots
# $$
#
# ## Moving Average MA(q)
#
# > The current value of the time-series can be modeled as a weighted sum of past values of the forecast error.
#
# ⚠️ This has not much to do with the moving/rolling average operation of pandas
#
# $$
# F_{MA}(y_{t-1}, y_{t-2}, \dots) = \beta_1\epsilon_{t-1} + \beta_2\epsilon_{t-2} + \dots
# $$
#
#
#
# ## Seasonal s (P, D, Q)
#
# > To remove seasonality the ARIMA model is applied to seasonal differences and lags.

# %% [markdown]
# # Forecasts applied to real data
#
# #### In the long run, ARIMA models "just" forecast the trend and seasonal part of the time series!

# %%
y = sns.load_dataset('flights')
y['month'] = y['month'].cat.codes + 1 #converts months to numbers
y['day'] = 1 #use first of each month
y.index = pd.to_datetime(y[['year', 'month', 'day']]) #creates datetime index
y = y['passengers']
y.head(3)
# Out:
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# Name: passengers, dtype: int64

# %%
y.plot(
    figsize=(12, 6),
    title='Flights',
    ylabel='Passengers',
    xlabel='Time'
)
sns.despine()

# %% [markdown]
# ## How can we make the time series stationary?
#
# - remove trend: first difference (d=1)
# - remove seasonality: seasonal difference (D=1, m=12)
# - remove changes in variance: box-cox/ log transformation

# %%
y.diff(1).diff(12).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## AutoARIMA

# %%
y
# Out:
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: passengers, Length: 144, dtype: int64

# %%
arima = pm.AutoARIMA(
    m=12,              # seasonality cycle
    d=1,               # apply differences
    D=1,               # apply seasonal difference
    maxiter=10000,
    seasonal=True
)

arima.fit(y)
arima.summary()
# Out:
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  144
# Model:             SARIMAX(2, 1, 1)x(0, 1, [], 12)   Log Likelihood                -504.923
# Date:                             Thu, 28 Apr 2022   AIC                           1017.847
# Time:                                     11:26:57   BIC                           1029.348
# Sample:                                          0   HQIC                          1022.520
#                                              - 144
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5960      0.085      6.987      0.000       0.429       0.763
# ar.L2          0.2143      0.091      2.343      0.019       0.035       0.393
# ma.L1         -0.9819      0.038    -25.602      0.000      -1.057      -0.907
# sigma2       129.3167     14.557      8.883      0.000     100.785     157.848
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 7.68
# Prob(Q):                              0.98   Prob(JB):                         0.02
# Heteroskedasticity (H):               2.33   Skew:                            -0.01
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# forecast for the next 5 years with uncertainty area
y_forecast, ci = arima.predict(n_periods=12*5, return_conf_int=True)

# create some date values for the forecast horizon
index_vals = pd.date_range('1961-01-01', '1965-12-01', freq='MS')


plt.figure(figsize=(12,6))
plt.plot(y.index.values, y.values)
plt.fill_between(index_vals.values, ci[:,0], ci[:, 1], alpha=0.7, color='lightgrey', label='95% CI')
plt.plot(index_vals.values, y_forecast, label='Passenger Demand Forecast', marker='.')
sns.despine()
plt.legend()

# %% [markdown]
# ## Residual analysis

# %%
# is the error truly random?
y_fit = arima.predict_in_sample()
y_fit = pd.Series(y_fit, index=y.index)
p = plot_acf(y-y_fit)
# Out:
# /Users/arjunharidas/miniforge3/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "

# %% [markdown]
# ## Pros and Cons
#
# - it's a good baseline and good starter
# - offers confidence intervals, uncertainty quantification
# - good performance
#
#
# - needs univariate numeric time series data
# - restrictive model function
# - unable to model complex seasonality (solution: use additional dummy matrix as feature matrix)
