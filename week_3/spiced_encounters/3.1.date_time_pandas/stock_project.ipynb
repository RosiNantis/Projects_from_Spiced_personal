# %%
# import packages
import pandas as pd
from datetime import datetime
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rc

plt.rcParams['figure.figsize'] = (20, 8)
plt.rcParams['axes.linewidth'] = 2
rc('font', **{'family':'serif','serif':['Helvetica']})
#rc('text', usetex=True)
plt.rc('xtick',labelsize = 20)
plt.rc('ytick',labelsize = 20)
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['legend.fontsize'] = 25

# %%
# import the data
stock = pd.read_csv('stock_px.csv', index_col=0, parse_dates=True)
stock.head()
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93

# %%
stock.index.resolution
# Out:
# 'day'

# %%
stock.info
# Out:
# <bound method DataFrame.info of               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]>

# %%
stock.loc['02/1/2003':'02/1/2004']
# Out:
#              AAPL   MSFT    XOM      SPX
# 2003-02-03   7.33  19.08  28.52   860.32
# 2003-02-04   7.30  18.59  28.52   848.20
# 2003-02-05   7.22  18.45  28.11   843.59
# 2003-02-06   7.22  18.63  27.87   838.15
# 2003-02-07   7.07  18.30  27.66   829.69
# ...           ...    ...    ...      ...
# 2004-01-26  11.51  22.83  35.18  1155.37
# 2004-01-27  11.53  22.40  34.88  1144.05
# 2004-01-28  11.26  21.97  34.56  1128.48
# 2004-01-29  11.34  22.13  35.12  1134.11
# 2004-01-30  11.28  21.92  34.54  1131.13
#
# [251 rows x 4 columns]

# %%
sns.set(style="ticks")
fig, ax = plt.subplots(4)
fig.tight_layout()

g1 = sns.lineplot(x=stock.index, y = stock["AAPL"],data = stock, ax=ax[0])
g2 = sns.lineplot(x=stock.index, y = stock["MSFT"],data = stock, ax=ax[1])
g3 = sns.lineplot(x=stock.index, y = stock["XOM"],data = stock, ax=ax[2])
g4 = sns.lineplot(x=stock.index, y = stock["SPX"],data = stock, ax=ax[3])

# %%
stock.describe()
# Out:
#               AAPL         MSFT          XOM          SPX
# count  2214.000000  2214.000000  2214.000000  2214.000000
# mean    125.516147    23.945452    59.558744  1183.773311
# std     107.394693     3.255198    16.725025   180.983466
# min       6.560000    14.330000    26.210000   676.530000
# 25%      37.135000    21.700000    49.492500  1077.060000
# 50%      91.455000    24.000000    62.970000  1189.260000
# 75%     185.605000    26.280000    72.510000  1306.057500
# max     422.000000    34.070000    87.480000  1565.150000
